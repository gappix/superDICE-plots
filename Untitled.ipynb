# %%
invisible(source("RICEx_datamng/RICEx_50_experiments_data_central_hub.R"))
invisible(source("RICEx_utils/RICEx_10_regions_mappings.R"))
invisible(source("RICEx_plots/RICEx_plots.R"))
# Out:
# Warning message:
# "package 'purrr' was built under R version 3.6.2"Warning message:
# "package 'stringr' was built under R version 3.6.2"Warning message:
# "package 'crayon' was built under R version 3.6.2"Warning message:
# "package 'tibble' was built under R version 3.6.2"Warning message:
# "package 'ggplot2' was built under R version 3.6.2"Warning message:
# "package 'ggspatial' was built under R version 3.6.2"Warning message:
# "package 'ggrepel' was built under R version 3.6.2"Warning message:
# "package 'raster' was built under R version 3.6.2"Warning message:
# "package 'sp' was built under R version 3.6.3"Warning message:
# "package 'sf' was built under R version 3.6.2"Warning message:
# "package 'conflicted' was built under R version 3.6.2"[conflicted] Will prefer dplyr::filter over any other package
# [conflicted] Will prefer dplyr::select over any other package
# Warning message:
# "package 'latex2exp' was built under R version 3.6.2"Warning message:
# ...

# %%
mygdx <- gdx('../RICEx-Main-Exp/kali_burke_test/Comparison_Burke_RICEx_bau_results.gdx')

# %%
BurkeDF = mygdx['damages_burke']
RICExDF =  mygdx['damages_iam']
BurkeDF
# Out:
#      ssp  t   n      value
# 1    ssp1 1   arg    1e-14
# 2    ssp1 1   aus    1e-14
# 3    ssp1 1   aut    1e-14
# 4    ssp1 1   bel    1e-14
# 5    ssp1 1   bgr    1e-14
# 6    ssp1 1   blt    1e-14
# 7    ssp1 1   bra    1e-14
# 8    ssp1 1   can    1e-14
# 9    ssp1 1   chl    1e-14
# 10   ssp1 1   chn    1e-14
# 11   ssp1 1   cor    1e-14
# 12   ssp1 1   cro    1e-14
# 13   ssp1 1   dnk    1e-14
# 14   ssp1 1   egy    1e-14
# 15   ssp1 1   esp    1e-14
# 16   ssp1 1   fin    1e-14
# 17   ssp1 1   fra    1e-14
# 18   ssp1 1   gbr    1e-14
# 19   ssp1 1   golf57 1e-14
# 20   ssp1 1   grc    1e-14
# 21   ssp1 1   hun    1e-14
# 22   ssp1 1   idn    1e-14
# 23   ssp1 1   irl    1e-14
# 24   ssp1 1   ita    1e-14
# 25   ssp1 1   jpn    1e-14
# 26   ssp1 1   meme   1e-14
# 27   ssp1 1   mex    1e-14
# 28   ssp1 1   mys    1e-14
# 29   ssp1 1   nde    1e-14
# 30   ssp1 1   nld    1e-14
# ...  ...  ... ...    ...
# 5671 ssp5 20  mys    -87.767431
# 5672 ssp5 20  nde    -91.802412
# ...

# %%
here()
PPstory5 = list()
PPstory5 = experiments_load_as_list(PPstory5,"PPstory2")
# Out:
# [1] "C:/Users/GaPPi/Documents/PhD Projects/RICEx-PROJECT/RICEx-Plots"
# Importing <<  28  >> new gdxfile experiments
# 1  Parsing:  C:/Users/GaPPi/Documents/PhD Projects/RICEx-PROJECT/RICEx-Plots/../RICEx-Results/PPstory2//ed57/RICEx_1x00_exPPstory2_OP_ed57_ssp1_cooppop_mcEDct4_clWco2_dmBK57SR_svFXcnv_wfDCE_rrCBA.gdx
# 2  Parsing:  C:/Users/GaPPi/Documents/PhD Projects/RICEx-PROJECT/RICEx-Plots/../RICEx-Results/PPstory2//ed57/RICEx_1x00_exPPstory2_OP_ed57_ssp1_nocooppop_mcEDct4_clWco2_dmBK57SR_svFXcnv_wfDCE_rrCBA.gdx
# 3  Parsing:  C:/Users/GaPPi/Documents/PhD Projects/RICEx-PROJECT/RICEx-Plots/../RICEx-Results/PPstory2//ed57/RICEx_1x00_exPPstory2_OP_ed57_ssp2_coopngsw_mcEDct4_clWco2_dmBK57LR_svFXcnv_wfDCE_rrCBA.gdx
# 4  Parsing:  C:/Users/GaPPi/Documents/PhD Projects/RICEx-PROJECT/RICEx-Plots/../RICEx-Results/PPstory2//ed57/RICEx_1x00_exPPstory2_OP_ed57_ssp2_coopngsw_mcEDct4_clWco2_dmBK57LRdiff_svFXcnv_wfDCE_rrCBA.gdx
# ...

# %%
bubba <- gdx('bubba.gdx')

# %%
aaa <- gdx('../RICEx-Results/PPstory5/ed57/RICEx_1x00_exPPstory5_OP_ed57_ssp1_cooppop_mcEDct4_clWco2_dmBKnSR_svFXcnv_wfDIS_rrCBA_xxgamma0.gdx')
# Out:
# Error in gdxInfo(filename, dump = F, returnDF = T): Could not read GDX file ../RICEx-Results/PPstory5/ed57/RICEx_1x00_exPPstory5_OP_ed57_ssp1_cooppop_mcEDct4_clWco2_dmBKnSR_svFXcnv_wfDIS_rrCBA_xxgamma0.gdx: Compression library not found (rc=0)
#
# Traceback:
#
# 1. gdx("../RICEx-Results/PPstory5/ed57/RICEx_1x00_exPPstory5_OP_ed57_ssp1_cooppop_mcEDct4_clWco2_dmBKnSR_svFXcnv_wfDIS_rrCBA_xxgamma0.gdx")
# 2. gdxInfo(filename, dump = F, returnDF = T)

# %%
Error in gdxInfo(filename, dump = F, returnDF = T):  Compression library not found (rc=0)
